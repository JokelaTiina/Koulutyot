# %% [markdown]
# ## Pandas-tehtävät OSA 2

# %% [markdown]
# #### Tehtävä 1. Lue edellisen harjoituksen lopussa tallennetun data_export.csv-tiedoston sisältö dataframeen siten, että Unnamed 0 -saraketta ei synny tiedoston lukemisen yhteydessä.

# %%
import pandas as pd
exercise2_dataframe = pd.read_csv('data_export.csv', index_col=0)
exercise2_dataframe
# Out:
#      sarake1   sarake2   sarake3
# 0        NaN  0.380058  0.919389
# 1   0.922251  0.490721  0.133932
# 3   0.363707  0.878349  0.485700
# 6   0.323134  0.036466  0.186775
# 7   0.467610  0.850993  0.377558
# 8   0.303299  0.096971  0.451031
# 9   0.733485  0.591996  0.658924
# 10  0.641628  0.251886  0.274987
# 12  0.319906  0.489200  0.990319
# 13  0.780267  0.458454  0.053428
# 15  0.935875  0.698276  0.446885
# 17  0.273193  0.300307  0.768270
# 18  0.467060  0.225161  0.911570
# 20  0.300589  0.455980  0.292225
# 21  0.859970  0.346539  0.364629
# 22  0.842364  0.093485  0.662066
# 23  0.781693  0.573344  0.815692
# 24  0.788949  0.945625  0.852690

# %% [markdown]
# #### Tehtävä 2. Pudota rivit, joissa esiintyy nan-arvo

# %%
exercise2_dataframe.dropna(inplace=True)
exercise2_dataframe
# Out:
#      sarake1   sarake2   sarake3
# 1   0.922251  0.490721  0.133932
# 3   0.363707  0.878349  0.485700
# 6   0.323134  0.036466  0.186775
# 7   0.467610  0.850993  0.377558
# 8   0.303299  0.096971  0.451031
# 9   0.733485  0.591996  0.658924
# 10  0.641628  0.251886  0.274987
# 12  0.319906  0.489200  0.990319
# 13  0.780267  0.458454  0.053428
# 15  0.935875  0.698276  0.446885
# 17  0.273193  0.300307  0.768270
# 18  0.467060  0.225161  0.911570
# 20  0.300589  0.455980  0.292225
# 21  0.859970  0.346539  0.364629
# 22  0.842364  0.093485  0.662066
# 23  0.781693  0.573344  0.815692
# 24  0.788949  0.945625  0.852690

# %% [markdown]
# #### Tehtävä 3. Muuta viidennen ja kymmenennen rivin kaikiksi arvoiksi nan

# %%
exercise2_dataframe.iloc[[4,9]] = float("nan") 
#exercise2_dataframe

# %% [markdown]
# #### Tehtävä 4. Tulosta nan-arvojen määrä jokaisesta sarakkeesta DataFrame-objektista

# %%
#exercise2_dataframe.isna().sum()

# %% [markdown]
# #### Tehtävä 5. Täytä edellä tehdyt nan-arvot lineaarisella interpolaatiolla

# %%
exercise2_dataframe.interpolate(method='linear')
# Out:
#      sarake1   sarake2   sarake3
# 1   0.922251  0.490721  0.133932
# 3   0.363707  0.878349  0.485700
# 6   0.323134  0.036466  0.186775
# 7   0.467610  0.850993  0.377558
# 8   0.600548  0.721495  0.518241
# 9   0.733485  0.591996  0.658924
# 10  0.641628  0.251886  0.274987
# 12  0.319906  0.489200  0.990319
# 13  0.780267  0.458454  0.053428
# 15  0.526730  0.379381  0.410849
# 17  0.273193  0.300307  0.768270
# 18  0.467060  0.225161  0.911570
# 20  0.300589  0.455980  0.292225
# 21  0.859970  0.346539  0.364629
# 22  0.842364  0.093485  0.662066
# 23  0.781693  0.573344  0.815692
# 24  0.788949  0.945625  0.852690

# %% [markdown]
# #### Tehtävä 6. Vaihda `sarake1`:n viimeiseksi arvoksi 94 ja `sarake3`:n viimeiseksi arvoksi 45

# %%
exercise2_dataframe.loc[24,'sarake1'] = 94
exercise2_dataframe.loc[24, 'sarake3'] = 45
#exercise2_dataframe.replace({"sarake1": {0.788949:94}}, inplace=True)
exercise2_dataframe
# Out:
#       sarake1   sarake2    sarake3
# 1    0.922251  0.490721   0.133932
# 3    0.363707  0.878349   0.485700
# 6    0.323134  0.036466   0.186775
# 7    0.467610  0.850993   0.377558
# 8         NaN       NaN        NaN
# 9    0.733485  0.591996   0.658924
# 10   0.641628  0.251886   0.274987
# 12   0.319906  0.489200   0.990319
# 13   0.780267  0.458454   0.053428
# 15        NaN       NaN        NaN
# 17   0.273193  0.300307   0.768270
# 18   0.467060  0.225161   0.911570
# 20   0.300589  0.455980   0.292225
# 21   0.859970  0.346539   0.364629
# 22   0.842364  0.093485   0.662066
# 23   0.781693  0.573344   0.815692
# 24  94.000000  0.945625  45.000000

# %% [markdown]
# #### Tehtävä 7. Lisää uusi sarake DataFrame-objektiin (`sarake4`), joka koostuu sarakkeiden `sarake1` ja `sarake3` summasta

# %%
exercise2_dataframe["sarake4"] = exercise2_dataframe["sarake1"] + exercise2_dataframe["sarake3"]
#exercise2_dataframe

# %% [markdown]
# #### Tehtävä 8. Resetoi DataFrame-objektin indeksi ja tulosta rivien määrä

# %%
exercise2_dataframe.reset_index(drop=True, inplace=True)
#exercise2_dataframe

# %%
print(len(exercise2_dataframe.index))
# Out:
# 17

# %% [markdown]
# #### Tehtävä 9. Tee DataFrame-objektin mittainen aikasarjadata haluamallasi aikavälillä ja tee siitä indeksisarake

# %%
timeserie = pd.date_range(start="1/1/2020", end="31/5/2021", freq="1M")
#timeserie

# %%
exercise2_dataframe = exercise2_dataframe.set_index(timeserie)

# %% [markdown]
# #### Tehtävä 10. Muuta `sarake1` kaikki arvot merkkijonoiksi, joissa jokainen nolla on korvattu isolla 'ND'-kirjainyhdistelmällä.

# %%
#exercise2_dataframe['sarake1'] = exercise2_dataframe['sarake1'].astype(str)
#exercise2_dataframe

# %%
#exercise2_dataframe['sarake1'].dtypes

# %%
#exercise2_dataframe['sarake1'] = exercise2_dataframe['sarake1'].apply(lambda x: x.replace('0', 'ND'))
#exercise2_dataframe

# %%
# Toinen tapa, jolla muutokset tehdään samalla kertaa
exercise2_dataframe['sarake1'] = exercise2_dataframe.iloc[:,0:18].applymap(lambda x: str(x)).applymap(lambda x: x.replace('0', 'ND'))
exercise2_dataframe
# Out:
#                             sarake1   sarake2    sarake3     sarake4
# 2020-01-31    ND.92225ND592ND455354  0.490721   0.133932    1.056182
# 2020-02-29     ND.3637ND65716836567  0.878349   0.485700    0.849407
# 2020-03-31     ND.32313386814ND7583  0.036466   0.186775    0.509909
# 2020-04-30   ND.4676ND99556ND15ND96  0.850993   0.377558    0.845168
# 2020-05-31                      nan       NaN        NaN         NaN
# 2020-06-30      ND.7334853147358118  0.591996   0.658924    1.392409
# 2020-07-31     ND.641628229ND317612  0.251886   0.274987    0.916615
# 2020-08-31  ND.3199ND554258ND25ND83  0.489200   0.990319    1.310225
# 2020-09-30     ND.78ND2672238818178  0.458454   0.053428    0.833695
# 2020-10-31                      nan       NaN        NaN         NaN
# 2020-11-30    ND.2731929NDND6731526  0.300307   0.768270    1.041463
# 2020-12-31  ND.467ND6NDND4ND1299349  0.225161   0.911570    1.378630
# 2021-01-31  ND.3NDND5888788521NDND1  0.455980   0.292225    0.592814
# 2021-02-28    ND.8599699ND1ND91ND25  0.346539   0.364629    1.224599
# 2021-03-31     ND.8423644152934ND61  0.093485   0.662066    1.504430
# 2021-04-30     ND.78169332392ND8187  0.573344   0.815692    1.597386
# 2021-05-31                    94.ND  0.945625  45.000000  139.000000

# %% [markdown]
# #### Tehtävä 11. Tee DataFrame-objektista kopio, jonka sarakkeiden nimet on muutettu seuraaviksi : `sarake5`, `sarake6`, `sarake7`, `sarake8`. Tämän jälkeen tee yksi iso DataFrame-objekti, joka koostuu alkuperäisestä DataFramesta sekä kopiosta niin, että ne on lisätty vierekkäin.
#
#
# | sarake1        | sarake2           | sarake3  | sarake4 | sarake5      | sarake6 | sarake7 | sarake8 |
# | ------------- |:-------------:| -----:| ------------- |:-------------:| -----:|-----:|-----:|
# | 0.1      | 0.2 | 0.3 | ... | ...  | ... | ... | ... |

# %%
exercise2_dataframe_copy = exercise2_dataframe.copy().rename(columns={'sarake1': 'sarake5', 'sarake2': 'sarake6', 'sarake3': 'sarake7', 'sarake4': 'sarake8'})
#exercise2_dataframe_copy

# %%
dataframes_sidebyside = pd.concat([exercise2_dataframe, exercise2_dataframe_copy], axis = 1)
dataframes_sidebyside
# Out:
#                             sarake1   sarake2    sarake3     sarake4  \
# 2020-01-31    ND.92225ND592ND455354  0.490721   0.133932    1.056182
# 2020-02-29     ND.3637ND65716836567  0.878349   0.485700    0.849407
# 2020-03-31     ND.32313386814ND7583  0.036466   0.186775    0.509909
# 2020-04-30   ND.4676ND99556ND15ND96  0.850993   0.377558    0.845168
# 2020-05-31                      nan       NaN        NaN         NaN
# 2020-06-30      ND.7334853147358118  0.591996   0.658924    1.392409
# 2020-07-31     ND.641628229ND317612  0.251886   0.274987    0.916615
# 2020-08-31  ND.3199ND554258ND25ND83  0.489200   0.990319    1.310225
# 2020-09-30     ND.78ND2672238818178  0.458454   0.053428    0.833695
# 2020-10-31                      nan       NaN        NaN         NaN
# 2020-11-30    ND.2731929NDND6731526  0.300307   0.768270    1.041463
# 2020-12-31  ND.467ND6NDND4ND1299349  0.225161   0.911570    1.378630
# 2021-01-31  ND.3NDND5888788521NDND1  0.455980   0.292225    0.592814
# 2021-02-28    ND.8599699ND1ND91ND25  0.346539   0.364629    1.224599
# 2021-03-31     ND.8423644152934ND61  0.093485   0.662066    1.504430
# 2021-04-30     ND.78169332392ND8187  0.573344   0.815692    1.597386
# 2021-05-31                    94.ND  0.945625  45.000000  139.000000
#
#                             sarake5   sarake6    sarake7     sarake8
# 2020-01-31    ND.92225ND592ND455354  0.490721   0.133932    1.056182
# 2020-02-29     ND.3637ND65716836567  0.878349   0.485700    0.849407
# 2020-03-31     ND.32313386814ND7583  0.036466   0.186775    0.509909
# 2020-04-30   ND.4676ND99556ND15ND96  0.850993   0.377558    0.845168
# 2020-05-31                      nan       NaN        NaN         NaN
# 2020-06-30      ND.7334853147358118  0.591996   0.658924    1.392409
# 2020-07-31     ND.641628229ND317612  0.251886   0.274987    0.916615
# 2020-08-31  ND.3199ND554258ND25ND83  0.489200   0.990319    1.310225
# 2020-09-30     ND.78ND2672238818178  0.458454   0.053428    0.833695
# 2020-10-31                      nan       NaN        NaN         NaN
# 2020-11-30    ND.2731929NDND6731526  0.300307   0.768270    1.041463
# 2020-12-31  ND.467ND6NDND4ND1299349  0.225161   0.911570    1.378630
# 2021-01-31  ND.3NDND5888788521NDND1  0.455980   0.292225    0.592814
# 2021-02-28    ND.8599699ND1ND91ND25  0.346539   0.364629    1.224599
# 2021-03-31     ND.8423644152934ND61  0.093485   0.662066    1.504430
# 2021-04-30     ND.78169332392ND8187  0.573344   0.815692    1.597386
# 2021-05-31                    94.ND  0.945625  45.000000  139.000000

# %% [markdown]
# #### Tehtävä 12. Sijoita `sarake5`:n viimeinen arvo muuttujaan sekä `sarake3`:n viimeinen arvo erilliseen muuttujaan juuri tehdystä DataFrame-objektista merkkijonomuodossa. Yhdistä kyseiset muuttujat merkkijonona ja poista kaksi viimeistä merkkiä lopputuloksesta. Lopuksi poista kaikki pisteet `.`.

# %%
fifth_column_last_item = exercise2_dataframe_copy.iloc[16,0]
fifth_column_last_item
# Out:
# '94.ND'

# %%
third_column_last_item = exercise2_dataframe.iloc[16,2]
third_column_last_item
# Out:
# 45.0

# %%
strings_together = str(fifth_column_last_item) + str(third_column_last_item)
strings_together
# Out:
# '94.ND45.0'

# %%
remove_two_chars = strings_together[:-2]
remove_two_chars
# Out:
# '94.ND45'

# %%
without_dots = strings_together.replace('.', '')
without_dots
# Out:
# '94ND450'
